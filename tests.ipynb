# %% [markdown]
# # logging tests

# %%
import os
import logging

# %%
logging.Logger
# Out:
# logging.Logger

# %%
logging.getLogger()
# Out:
# <RootLogger root (WARNING)>

# %%
logging.getLogger("__name__")
# Out:
# <Logger __name__ (WARNING)>

# %%
logger = logging.getLogger()

# %%
logger.handlers
# Out:
# []

# %%
not logger.handlers
# Out:
# True
